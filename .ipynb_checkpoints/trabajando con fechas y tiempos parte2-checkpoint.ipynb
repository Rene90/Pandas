# %%
import pandas as pd

# %%
pd.date_range(start = "2012-09-09", periods =25, freq= "B")
# Out:
# DatetimeIndex(['2012-09-10', '2012-09-11', '2012-09-12', '2012-09-13',
#                '2012-09-14', '2012-09-17', '2012-09-18', '2012-09-19',
#                '2012-09-20', '2012-09-21', '2012-09-24', '2012-09-25',
#                '2012-09-26', '2012-09-27', '2012-09-28', '2012-10-01',
#                '2012-10-02', '2012-10-03', '2012-10-04', '2012-10-05',
#                '2012-10-08', '2012-10-09', '2012-10-10', '2012-10-11',
#                '2012-10-12'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start = "2012-09-09", periods =25, freq= "W-TUE")
# Out:
# DatetimeIndex(['2012-09-11', '2012-09-18', '2012-09-25', '2012-10-02',
#                '2012-10-09', '2012-10-16', '2012-10-23', '2012-10-30',
#                '2012-11-06', '2012-11-13', '2012-11-20', '2012-11-27',
#                '2012-12-04', '2012-12-11', '2012-12-18', '2012-12-25',
#                '2013-01-01', '2013-01-08', '2013-01-15', '2013-01-22',
#                '2013-01-29', '2013-02-05', '2013-02-12', '2013-02-19',
#                '2013-02-26'],
#               dtype='datetime64[ns]', freq='W-TUE')

# %%
pd.date_range(end = "1999-12-31",periods = 20, freq="D")
# Out:
# DatetimeIndex(['1999-12-12', '1999-12-13', '1999-12-14', '1999-12-15',
#                '1999-12-16', '1999-12-17', '1999-12-18', '1999-12-19',
#                '1999-12-20', '1999-12-21', '1999-12-22', '1999-12-23',
#                '1999-12-24', '1999-12-25', '1999-12-26', '1999-12-27',
#                '1999-12-28', '1999-12-29', '1999-12-30', '1999-12-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # The dt Accessor

# %%
bunch = pd.date_range(start = "2000-01-01", end = "2010-12-31", freq="24D")

# %%
s = pd.Series(bunch)
s.head()
# Out:
# 0   2000-01-01
# 1   2000-01-25
# 2   2000-02-18
# 3   2000-03-13
# 4   2000-04-06
# dtype: datetime64[ns]

# %%
s.dt.day
s.dt.month
s.dt.weekday_name
# Out:
# 0       Saturday
# 1        Tuesday
# 2         Friday
# 3         Monday
# 4       Thursday
# 5         Sunday
# 6      Wednesday
# 7       Saturday
# 8        Tuesday
# 9         Friday
# 10        Monday
# 11      Thursday
# 12        Sunday
# 13     Wednesday
# 14      Saturday
# 15       Tuesday
# 16        Friday
# 17        Monday
# 18      Thursday
# 19        Sunday
# 20     Wednesday
# 21      Saturday
# 22       Tuesday
# 23        Friday
# 24        Monday
# 25      Thursday
# 26        Sunday
# 27     Wednesday
# 28      Saturday
# 29       Tuesday
#          ...
# 138       Sunday
# 139    Wednesday
# 140     Saturday
# 141      Tuesday
# 142       Friday
# 143       Monday
# 144     Thursday
# 145       Sunday
# 146    Wednesday
# 147     Saturday
# 148      Tuesday
# 149       Friday
# 150       Monday
# 151     Thursday
# 152       Sunday
# 153    Wednesday
# 154     Saturday
# 155      Tuesday
# 156       Friday
# 157       Monday
# 158     Thursday
# ...

# %%
mask = s.dt.is_quarter_start
s[mask]
# Out:
# 0     2000-01-01
# 19    2001-04-01
# 38    2002-07-01
# 137   2009-01-01
# dtype: datetime64[ns]

# %%
mask = s.dt.is_month_start
s[mask]
# Out:
# 0     2000-01-01
# 19    2001-04-01
# 38    2002-07-01
# 104   2006-11-01
# 109   2007-03-01
# 137   2009-01-01
# 142   2009-05-01
# dtype: datetime64[ns]

# %% [markdown]
# # Importando un data set de finzanzas con pandas datareader

# %%
import pandas as pd
import datetime as dt
from pandas_datareader import data

# %%
company = "MSFT" #microsoft
start = "2010-01-01"
end = "2017-12-31"
data.DataReader(name = company, data_source = "google", start = start, end =end)
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-25-bd9119d23830> in <module>
#       2 start = "2010-01-01"
#       3 end = "2017-12-31"
# ----> 4 data.DataReader(name = company, data_source = "google", start = start, end =end)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     314                                  chunksize=25,
#     315                                  retry_count=retry_count, pause=pause,
# --> 316                                  session=session).read()
#     317
#     318     elif data_source == "iex":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/google/daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize)
# ...

# %%
##Selecting from a dataframe with a datetimeIndex
stocks.loc["2014-03-04"]  #por etiqueta de indice
stocks.iloc[300] #por posicion
stocks.ix["2014-03-04"]
stocks.ix[300]
stocks.loc["2013-10-01":"2013-10-07"]
bthdays = pd.date_range(start = "1991-04-12", end= "2017-12-31", freq =pd.DateOffset(years = 1) )
mask = stocks.index.isin(birthdays)
stocks.loc[mask]

# %%
someday = stocks.index[500]
someday.day
someday.month
someday.year
someday.weekday_name
stocks.insert(0,"Day of Week", stocks.index.weekday_name)
stocks.insert(1,"Is start of month", stocks.index.is_month_start)

# %%
stocks.truncate(before = "2011-02-05", after = "2011-02-28")

# %% [markdown]
# # pd.dateoffset objects

# %%
data.DataReader(name="GOOG", data_source = "google", start= dt.date(2000,1,1),end= dt.datetime.now())
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-26-50566e6d7f5b> in <module>
# ----> 1 data.DataReader(name="GOOG", data_source = "google", start= dt.date(2000,1,1),end= dt.datetime.now())
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     314                                  chunksize=25,
#     315                                  retry_count=retry_count, pause=pause,
# --> 316                                  session=session).read()
#     317
#     318     elif data_source == "iex":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas_datareader/google/daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize)
#      34     def __init__(self, symbols=None, start=None, end=None, retry_count=3,
# ...

# %%
stocks.index + pd.DateOffSet(days=5)
stocks.index + pd.tseries.offsets.MonthEnd()#redondea al final del mes

# %% [markdown]
# # Timedelta

# %%
timeA = pd.Timestamp("2016-03-31 04:35:16 PM")
timeB = pd.Timestamp("2016-03-20 02:16:49 AM")

# %%
timeA - timeB
# Out:
# Timedelta('11 days 14:18:27')

# %%
pd.Timedelta(days = 3, minutes = 45, hours =12, weeks = 8)
# Out:
# Timedelta('59 days 12:45:00')

# %%
shipping = pd.read_csv("ecommerce.csv", index_col = "ID", parse_dates = ["order_date", "delivery_date"])
shipping.head(3)
# Out:
#    order_date delivery_date
# ID
# 1  1998-05-24    1999-02-05
# 2  1992-04-22    1998-03-06
# 4  1991-02-10    1992-08-26

# %%
shipping["Delivery_time"] = shipping["delivery_date"] - shipping["order_date"]
shipping.head(3)
# Out:
#    order_date delivery_date Delivery_time
# ID
# 1  1998-05-24    1999-02-05      257 days
# 2  1992-04-22    1998-03-06     2144 days
# 4  1991-02-10    1992-08-26      563 days

# %%
shipping["Twice"] = shipping["delivery_date"] + shipping["Delivery_time"]

# %%
shipping.head(3)
# Out:
#    order_date delivery_date Delivery_time      Twice
# ID
# 1  1998-05-24    1999-02-05      257 days 1999-10-20
# 2  1992-04-22    1998-03-06     2144 days 2004-01-18
# 4  1991-02-10    1992-08-26      563 days 1994-03-12

# %%
mask = shipping["Delivery_time"] > "300 days"
shipping[mask]
# Out:
#     order_date delivery_date Delivery_time      Twice
# ID
# 2   1992-04-22    1998-03-06     2144 days 2004-01-18
# 4   1991-02-10    1992-08-26      563 days 1994-03-12
# 5   1992-07-21    1997-11-20     1948 days 2003-03-22
# 7   1993-09-02    1998-06-10     1742 days 2003-03-18
# 9   1990-01-25    1994-10-02     1711 days 1999-06-09
# 10  1992-02-23    1998-12-30     2502 days 2005-11-05
# 11  1996-07-12    1997-07-14      367 days 1998-07-16
# 18  1995-06-18    1997-10-13      848 days 2000-02-08
# 20  1992-10-17    1998-10-06     2180 days 2004-09-24
# 23  1992-05-30    1999-08-15     2633 days 2006-10-30
# 26  1996-04-11    1998-05-04      753 days 2000-05-26
# 32  1990-01-20    1998-07-24     3107 days 2007-01-25
# 33  1994-09-21    1996-10-12      752 days 1998-11-03
# 35  1993-09-10    1996-04-28      961 days 1998-12-15
# 36  1990-05-15    1994-02-14     1371 days 1997-11-16
# 39  1990-03-26    1993-01-25     1036 days 1995-11-27
# ...
